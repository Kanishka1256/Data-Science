# %%
import pandas as pd

# %%
from io import StringIO

# %%
json_data="""
[
    {"Roll_no":1,
     "Name":"Raju",
     "Marks":99
    },
    {
     "Roll_no":2,
     "Name":"Ravi",
     "Marks":98
    },
    {
     "Roll_no":3,
     "Name":"Ramu",
     "Marks":97
    }
]
"""

# %%
df=pd.read_json(StringIO(json_data))
print("Parsed data\n")
print(df)
# Out:
# Parsed data
#
#    Roll_no  Name  Marks
# 0        1  Raju     99
# 1        2  Ravi     98
# 2        3  Ramu     97
