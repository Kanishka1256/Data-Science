# %%
import pandas as pd

# %%
df=pd.read_json("student.json")

# %%
print("Data\n")
print(df)
# Out:
# Data
#
#    Roll_no      Name Deaprtment  Ratings
# 0      101  Mammooty   Thriller        4
# 1      102        DQ      Drama        5
# 2      103    Tovino     Sci-Fi        5
# 3      104     Basil     Comedy        4
