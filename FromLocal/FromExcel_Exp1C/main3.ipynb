# %%
import pandas as pd

# %%
excel_data = pd.read_excel(
    "college_data.xlsx",
    sheet_name="students"
)

# %%
excel_data = pd.read_excel(
    "college_data.xlsx",
    sheet_name=None
)

print("Available sheets:")
print(excel_data.keys())

print("\nStudent sheet:")
print(excel_data["students"])

print("\nCourses sheet:")
print(excel_data["courses"])
# Out:
# Available sheets:
# dict_keys(['students', 'courses'])
#
# Student sheet:
#    Roll_no      Name Department  marks
# 0      101    Vishnu         It     95
# 1      102  Kanishka        cse     97
# 2      103  Shashank        csd     98
#
# Courses sheet:
#   course_id       course_Name  credit
# 0      c101            python       9
# 1      c102               sql       8
# 2      c103  machine learning       9
