# %%
import pandas as pd

# %%
df=pd.read_excel("student.xlsx",sheet_name="student_Details")

# %%
print("Data read from excel file:")
print(df)
# Out:
# Data read from excel file:
#    Roll_NO       Name Department  Marks
# 0      101     Vishnu         It     92
# 1      102   kanishka        cse     98
# 2      103   Shashank        csd     95
# 3      104  Kushvanth         ds     76
