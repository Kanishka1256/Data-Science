# %%
import pandas as pd

# %%
df=pd.read_csv("student.txt",sep="\t")

# %%
print(df)
# Out:
#    Roll_num Name Department  Percentage
# 0       101  ABC        CSE        92.5
# 1       102  DEF        ECE        89.0
# 2       103  GHI         IT        95.2
# 3       104  JKL       MECH        87.8
# 4       105  MNO      CIVIL        91.4
