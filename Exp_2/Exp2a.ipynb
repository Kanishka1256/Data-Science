# %%
import requests
import pandas as pd

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"
response=requests.get(url)
issues=response.json()
df_issues=pd.DataFrame(issues)

# %%
print(df_issues[['id','title','state','created_at']].head())
# Out:
#            id                                              title state  \
# 0  5132544163                   TRACKER: support for Python 3.15  open
# 1  5131820781     CLN: share checked integer extern declarations  open
# 2  5131484847  BUG: guard ArrowExtensionArray._replace_with_m...  open
# 3  5130207908             DOC: add whatsnew entry for c++20 bump  open
# 4  5130029826        ENH: Add excel_sep_hint parameter to to_csv  open
#
#              created_at
# 0  2026-08-12T15:28:32Z
# 1  2026-08-12T14:11:31Z
# 2  2026-08-12T13:36:15Z
# 3  2026-08-12T11:10:55Z
# 4  2026-08-12T10:48:23Z
